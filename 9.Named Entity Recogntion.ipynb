# %%
#!pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.3 MB/s eta 0:00:10
# ...

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
list(nlp.vocab.strings)
# Out:
# ['\t',
#  '\t\t',
#  '\t\x0b',
#  '\t\x0c',
#  '\t\r',
#  '\t\x1c',
#  '\t\x1d',
#  '\t\x1e',
#  '\t\x1f',
#  '\t ',
#  '\t\x85',
#  '\t\x85\u1680',
#  '\t\xa0',
#  '\t\u1680',
#  '\t\u2001',
#  '\t\u2005',
#  '\t\u2006',
#  '\t\u2007',
#  '\t\u2008',
#  '\t\u2009',
#  '\t\u200a',
#  '\t\u2028',
#  '\t\u205f',
#  '\t\u3000',
#  '\n',
#  '\n\t',
#  '\n\x0b',
#  '\n\r',
#  '\n\r\t',
#  '\n\x1c',
#  '\n ',
#  '\n\u1680',
#  '\n\u2001',
#  '\n\u2002',
#  '\n\u2003',
#  '\n\u2004',
#  '\n\u2005',
#  '\n\u2006',
#  '\n\u2007',
#  '\n\u2008',
#  '\n\u2009',
#  '\n\u200a',
#  '\n\u2029',
#  '\n\u202f',
#  '\n\u205f',
#  '\n\u3000',
#  '\x0b',
#  '\x0b\n',
#  '\x0b\x0b',
#  '\x0b\x0c',
#  '\x0b\r',
#  '\x0b ',
#  '\x0b\x85',
#  '\x0b\xa0',
#  '\x0b\u1680',
#  '\x0b\u2001',
#  '\x0b\u2002',
#  '\x0b\u2003',
#  '\x0b\u2005',
#  '\x0b\u2005\u2000',
#  '\x0b\u2006',
#  '\x0b\u2007',
#  '\x0b\u2008',
#  '\x0b\u200a',
#  '\x0b\u2028',
#  '\x0b\u2029',
#  '\x0b\u202f',
#  '\x0b\u205f\u2007',
# ...

# %%
doc = nlp(" Team India wii meet the Worldcup 2023 Finals against Australia in Ahmedabad ")

# %%
doc.ents
# Out:
# (Team India, Australia, Ahmedabad)

# %%
for i in doc.ents:
    print(f"{i.text}: {i.label_}")
# Out:
# Team India: ORG
# Australia: GPE
# Ahmedabad: GPE

# %%
#spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'
